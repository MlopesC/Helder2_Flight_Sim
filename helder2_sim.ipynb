# %% [markdown]
# # Getting Started

# %% [markdown]
# Here we go through a complete rocket trajectory simulation to get you started.
#
# Also, a more in detail complete description of the simulation can also be found in the [First Simulation Section of the RocketPy Documentation](https://docs.rocketpy.org/en/latest/user/first_simulation.html).
#
# If you want, you can open this notebook in Google Colab by clicking the badge below.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RocketPy-Team/rocketpy/blob/master/docs/notebooks/getting_started_colab.ipynb)
#
# Let's start by importing the rocketpy module.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from rocketpy import Environment, Flight, Rocket, SolidMotor

# %% [markdown]
# If you are using Jupyter Notebooks, it is recommended to run the following line to make matplotlib plots which will be shown later interactive and higher quality.

# %%
# %matplotlib inline

# %% [markdown]
# ## Setting Up a Simulation

# %% [markdown]
# ### Creating an Environment for Spaceport America
#
# The `Environment` class is used to define the atmosphere, the winds, and the gravity models.
#
# You can find more information about the `Environment` class in the [Environment Class Usage Docs](https://docs.rocketpy.org/en/latest/notebooks/environment/environment_class_usage.html).

# %%
env = Environment(latitude=-21.916667, longitude=-48.968000, elevation=610)

# %% [markdown]
# To get weather data from the GFS forecast, available online, we run the following lines.
#
# First, we set tomorrow's date.

# %%
import datetime

tomorrow = datetime.date.today() + datetime.timedelta(days=1)

env.set_date(
    (tomorrow.year, tomorrow.month, tomorrow.day, 12)
)  # Hour given in UTC time

# %% [markdown]
# Then, we tell env to use a GFS forecast to get the atmospheric conditions for flight.
#
# Don't mind the warning, it just means that not all variables, such as wind speed or atmospheric temperature, are available at all altitudes given by the forecast.

# %%
env.set_atmospheric_model(type="Forecast", file="GFS")

# %% [markdown]
# We can see what the weather will look like by calling the info method!

# %%
env.max_expected_height = 5000  # adjust the plots to this height
env.info()
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.7861 m/s²
# Acceleration of gravity at   5.000 km (ASL): 9.7721 m/s²
#
#
# Launch Site Details
#
# Launch Date: 2025-09-29 12:00:00 UTC
# Launch Site Latitude: -21.91667°
# Launch Site Longitude: -48.96800°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 89942.75 W    7571090.99 S
# Launch Site UTM zone: 23K
# Launch Site Surface Elevation: 472.3 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: Forecast
# Forecast Maximum Height: 5.000 km
# Forecast Time Period: from 2025-09-28 12:00:00 to 2025-10-14 12:00:00 utc
# Forecast Hour Interval: 3 hrs
# Forecast Latitude Range: From -90.0° to 90.0°
# Forecast Longitude Range: From 0.0° to 359.75°
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 2.89 m/s
# Surface Wind Direction: 63.39°
# Surface Wind Heading: 243.39°
# Surface Pressure: 962.88 hPa
# Surface Temperature: 301.18 K
# Surface Air Density: 1.114 kg/m³
# Surface Speed of Sound: 347.90 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6375.18 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
# Atmospheric Model Plots

# %% [markdown]
# ### Creating a Motor
#
# A solid rocket motor is used in this case. To create a motor, the SolidMotor class is used and the required arguments are given.
#
# The SolidMotor class requires the user to have a thrust curve ready. This can come either from a .eng file for a commercial motor, such as below, or a .csv file from a static test measurement.
#
# Besides the thrust curve, other parameters such as grain properties and nozzle dimensions must also be given.
#
# See [Solid Motor Class Usage Docs](https://docs.rocketpy.org/en/latest/user/motors/solidmotor.html) for more information.

# %%
# IMPORTANT: modify the file path below to match your own system

Honda_Felix = SolidMotor(
    thrust_source="Honda_Felix.eng",
    dry_mass=0.86,
    dry_inertia=(0.125, 0.125, 0.002),
    nozzle_radius=33 / 1000,
    grain_number=4,
    grain_density=1815,
    grain_outer_radius=30 / 1000,
    grain_initial_inner_radius=15 / 1000,
    grain_initial_height=117.75 / 1000,
    grain_separation=0 / 1000,
    grains_center_of_mass_position=0.397,
    center_of_dry_mass_position=0.317,
    nozzle_position=0,
    burn_time=1.47,
    throat_radius=11 / 1000,
    coordinate_system_orientation="nozzle_to_combustion_chamber",
)

# %% [markdown]
# **Pay special attention to _position_ related parameters:**
# More details on [Positions and Coordinate Systems](https://docs.rocketpy.org/en/latest/user/positions.html)

# %% [markdown]
# To see what our thrust curve looks like, along with other import properties, we invoke the info method yet again. You may try the all_info method if you want more information all at once!

# %%
Honda_Felix.info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.033 m
# Nozzle Throat Radius: 0.011 m
#
# Grain Details
# Number of Grains: 4
# Grain Spacing: 0.0 m
# Grain Density: 1815 kg/m3
# Grain Outer Radius: 0.03 m
# Grain Inner Radius: 0.015 m
# Grain Height: 0.11775 m
# Grain Volume: 0.000 m3
# Grain Mass: 0.453 kg
#
# Motor Details
# Total Burning Time: 1.47 s
# Total Propellant Mass: 1.813 kg
# Structural Mass Ratio: 0.322
# Average Propellant Exhaust Velocity: 554.028 m/s
# Average Thrust: 683.228 N
# Maximum Thrust: 832.1705 N at 1.44 s after ignition.
# Total Impulse: 1004.345 Ns

# %% [markdown]
# ### Creating a Rocket

# %% [markdown]
# A rocket is composed of several components. Namely, we must have a motor (good thing we have the Pro75M1670 ready), a couple of aerodynamic surfaces (nose cone, fins and tail) and parachutes (if we are not launching a missile).
#
# You can find more information about the `Rocket` class in the [Rocket Class Usage Docs](https://docs.rocketpy.org/en/latest/user/rocket.html).
#
# Let's start by initializing our rocket, named helder2, entering inertia properties, some dimensions and drag curves.
#
# **Pay special attention to _position_ related parameters:**
# More details on [Positions and Coordinate Systems](https://docs.rocketpy.org/en/latest/user/positions.html)

# %%
# IMPORTANT: modify the file paths below to match your own system

helder2 = Rocket(
    radius=130 / 2000,
    mass=3.3,
    inertia=(6.321, 6.321, 0.034),
    power_off_drag="Poweroffdrag.csv",   # arquivo na mesma pasta do script
    power_on_drag="Powerondrag.csv",     # arquivo na mesma pasta do script
    center_of_mass_without_motor=0,
    coordinate_system_orientation="tail_to_nose",
)

# Definição dos rail buttons
rail_buttons = helder2.set_rail_buttons(
    upper_button_position=0.0818,
    lower_button_position=-0.618,
    angular_position=45,
)

# %% [markdown]
# To add the motor to our rocket we need only inform what motor we are adding (Pro75M1670) and inform the position, in meters, of the motor's nozzle exit area relative to the previously defined coordinate system.

# %%
helder2.add_motor(Honda_Felix, position=-1.25)

# %% [markdown]
# #### Adding Aerodynamic Surfaces

# %% [markdown]
# Now we define the aerodynamic surfaces. They are really straight forward with special attention needed only for the position values. Here is a quick guide:
#
# - The positions given **must** be relative to the same coordinate system as the rockets;
# - Position of the Nosecone refers to the tip of the nose;
# - Position of fins refers to the point belonging to the root chord which is highest in the rocket coordinate system;
# - Position of the tail the point belonging to the tail which is highest in the rocket coordinate system.
#
# See more details in [Positions and Coordinate Systems](https://docs.rocketpy.org/en/latest/user/positions.html)

# %%
nose_cone = helder2.add_nose(length=0.55829, kind="vonKarman", position=1)

# Adicionando as aletas
fin_set = helder2.add_trapezoidal_fins(
    n=4,
    root_chord=0.150,
    tip_chord=0.100,
    span=0.176,
    position=-1.05,
    cant_angle=16.1,
    airfoil=("NACA0012-radians.txt", "radians"),  # arquivo na mesma pasta
)

# Adicionando a cauda
tail = helder2.add_tail(
    top_radius=0.0635, bottom_radius=0.0435, length=0.060, position=-1.05
)

# %% [markdown]
# To see all information regarding the rocket we just defined we run:

# %%
helder2.all_info()
# Out:
# Inertia Details
#
# Rocket Mass: 3.300 kg (without motor)
# Rocket Dry Mass: 4.160 kg (with unloaded motor)
# Rocket Loaded Mass: 5.973 kg
# Rocket Structural Mass Ratio: 0.696
# Rocket Inertia (with unloaded motor) 11: 7.040 kg*m2
# Rocket Inertia (with unloaded motor) 22: 7.040 kg*m2
# Rocket Inertia (with unloaded motor) 33: 0.036 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.065 m
# Rocket Frontal Area: 0.013273 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.193 m
# Rocket Center of Dry Mass - Nozzle Exit: 1.057 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.660 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.200 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 13.615/rad
# Tail Lift Coefficient Derivative: -1.013/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: 0.721 m
# Fins Center of Pressure position: -1.105 m
# Tail Center of Pressure position: -1.078 m
#
# Stability
#
# Center of Mass position (time=0): -0.393 m
# Center of Pressure position (time=0): -0.857 m
# Initial Static Margin (mach=0, time=0): 3.566 c
# Final Static Margin (mach=0, time=burn_out): 5.107 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.464 m
#
#
# Rocket Draw
# ----------------------------------------
# Mass Plots
# ----------------------------------------
# Aerodynamics Plots
# ----------------------------------------
# Drag Plots
# --------------------
# Stability Plots
# --------------------
# Thrust-to-Weight Plot
# ----------------------------------------

# %% [markdown]
# #### Adding Parachutes

# %% [markdown]
# Finally, we have parachutes! helder2 will have two parachutes, Drogue and Main. The Drogue parachute will open at apogee while the Main parachute will open at 800m above ground level
#
# For more details see [Adding Parachutes](https://docs.rocketpy.org/en/latest/user/rocket.html#adding-parachutes)

# %%
Main = helder2.add_parachute(
    "Main",
    cd_s=1.475,
    trigger=1000,
    sampling_rate=91.6,
    lag=1.5,
    noise=(0, 8.3, 0.5),
)

# %% [markdown]
# Just be careful if you run this last cell multiple times! If you do so, your rocket will end up with lots of parachutes which activate together, which may cause problems during the flight simulation. We advise you to re-run all cells which define our rocket before running this, preventing unwanted old parachutes. Alternatively, you can run the following lines to remove parachutes.
#
# ```python
# helder2.parachutes.remove(Drogue)
# helder2.parachutes.remove(Main)
# ```

# %% [markdown]
# ## Simulating a Flight
#
# Simulating a flight trajectory is as simple as initializing a Flight class object givin the rocket and environnement set up above as inputs. The launch rail inclination and heading are also given here.

# %%
test_flight = Flight(
    rocket=helder2, environment=env, rail_length=4.0, inclination=85, heading=90
)

# %% [markdown]
# ## Analyzing the Results
#
# RocketPy gives you many plots, thats for sure! They are divided into sections to keep them organized. Alternatively, see the Flight class documentation to see how to get plots for specific variables only, instead of all of them at once.

# %%
test_flight.all_info()
# Out:
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 472.26 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 0.923 | e1: -0.017 | e2: 0.040 | e3: -0.382
# Euler Angles - Spin φ : 45.00° | Nutation θ: -5.00° | Precession ψ: -90.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: 3.566 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: -2.58 m/s
# Lateral Surface Wind Speed: -1.30 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 4.0 m
# Launch Rail Inclination: 85.00°
# Launch Rail Heading: 90.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.266 s
# Rail Departure Velocity: 21.984 m/s
# Rail Departure Stability Margin: 3.728 c
# Rail Departure Angle of Attack: 7.412°
# Rail Departure Thrust-Weight Ratio: 10.752
# Rail Departure Reynolds Number: 1.751e+05
#
#
# Burn out State
#
# Burn out time: 1.470 s
# Altitude at burn out: 584.432 m (ASL) | 112.168 m (AGL)
# Rocket speed at burn out: 171.782 m/s
# Freestream velocity at burn out: 172.276 m/s
# Mach Number at burn out: 0.496
# Kinetic energy at burn out: 6.179e+04 J
#
#
# Apogee State
#
# Apogee Time: 11.542 s
# Apogee Altitude: 1214.638 m (ASL) | 742.374 m (AGL)
# Apogee Freestream Speed: 11.366 m/s
# Apogee X position: 162.191 m
# Apogee Y position: 5.670 m
# Apogee latitude: -21.9166160°
# Apogee longitude: -48.9664288°
#
#
# Parachute Events
#
# Parachute: Main
# 	Ejection time: 11.550 s
# 	Inflation time: 13.050 s
# 	Freestream speed at inflation: 17.513 m/s
# 	Altitude at inflation: 1204.661 m (ASL) | 732.397 m (AGL)
#
#
# Impact Conditions
#
# Time of impact: 114.684 s
# X impact: -41.772 m
# Y impact: -247.504 m
# Altitude impact: 472.264 m (ASL) | -0.000 m (AGL)
# Latitude: -21.9188914°
# Longitude: -48.9684047°
# Vertical velocity at impact: -7.048 m/s
# Number of parachutes triggered until impact: 1
#
#
# Stability Margin
#
# Initial Stability Margin: 3.566 c at 0.00 s
# Out of Rail Stability Margin: 3.728 c at 0.27 s
# Maximum Stability Margin: 5.204 c at 1.47 s
# Minimum Stability Margin: 3.566 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 171.863 m/s at 1.46 s
# Maximum Mach Number: 0.496 Mach at 1.46 s
# Maximum Reynolds Number: 1.339e+06 at 1.46 s
# Maximum Dynamic Pressure: 1.639e+04 Pa at 1.46 s
# Maximum Acceleration During Motor Burn: 154.490 m/s² at 1.44 s
# Maximum Gs During Motor Burn: 15.754 g at 1.44 s
# Maximum Acceleration After Motor Burn: 0.000 m/s² at 0.00 s
# Maximum Gs After Motor Burn: 0.000 Gs at 0.00 s
# Maximum Stability Margin: 5.204 c at 1.47 s
# Maximum Upper Rail Button Normal Force: 9.901 N
# Maximum Upper Rail Button Shear Force: 5.027 N
# Maximum Lower Rail Button Normal Force: 16.143 N
# Maximum Lower Rail Button Shear Force: 8.200 N
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 2112
# Number of Derivative Functions Evaluation: 204
# Average Function Evaluations per Time Step: 0.097
#
#
#
# Trajectory 3d Plot
# Trajectory Kinematic Plots
# Angular Position Plots
# Path, Attitude and Lateral Attitude Angle plots
# Trajectory Angular Velocity and Acceleration Plots
# Aerodynamic Forces Plots
# Rail Buttons Forces Plots
# Trajectory Energy Plots
# Trajectory Fluid Mechanics Plots
# Trajectory Stability and Control Plots
# Rocket and Parachute Pressure Plots
# Parachute:  Main

# %% [markdown]
# Export Flight Trajectory to a .kml file so it can be opened on Google Earth

# %%
test_flight.export_kml(
    file_name="trajectory.kml",
    extrude=True,
    altitude_mode="relative_to_ground",
)
# Out:
# File  trajectory.kml  saved with success!

# %% [markdown]
# ## Using Simulation for Design
#
# Here, we go through a couple of examples which make use of RocketPy in cool ways to help us design our rocket.

# %% [markdown]
# ### Apogee as a Function of Mass
#
# This one is a classic one! We always need to know how much our rocket's apogee will change when our payload gets heavier.

# %%
from rocketpy.utilities import apogee_by_mass

apogee_by_mass(flight=test_flight, min_mass=3, max_mass=5, points=100, plot=True)
# Out:
# 'Function from R1 to R1 : (Rocket Mass without motor (kg)) → (Apogee AGL (m))'

# %% [markdown]
# ### Out of Rail Speed as a Function of Mass
#
# Lets make a really important plot. Out of rail speed is the speed our rocket has when it is leaving the launch rail. This is crucial to make sure it can fly safely after leaving the rail. A common rule of thumb is that our rocket's out of rail speed should be 4 times the wind speed so that it does not stall and become unstable.

# %%
from rocketpy.utilities import liftoff_speed_by_mass

liftoff_speed_by_mass(flight=test_flight, min_mass=3.39, max_mass=5.22, points=10, plot=True)
# Out:
# 'Function from R1 to R1 : (Rocket Mass without motor (kg)) → (Out of Rail Speed (m/s))'

# %% [markdown]
# ### Dynamic Stability Analysis
#
# Ever wondered how static stability translates into dynamic stability? Different static margins result in different dynamic behavior, which also depends on the rocket's rotational inertial.
#
# Let's make use of RocketPy's helper class called Function to explore how the dynamic stability of helder2 varies if we change the fins span by a certain factor.

# %%
# Helper class
import copy

from rocketpy import Function

# Prepare a copy of the rocket
helder2 = copy.deepcopy(helder2)

# Prepare Environment Class
custom_env = Environment()
custom_env.set_atmospheric_model(type="custom_atmosphere", wind_v=-5)

# Simulate Different Static Margins by Varying Fin Position
simulation_results = []

for factor in [-0.5, -0.2, 0.1, 0.4, 0.7]:
    # Modify rocket fin set by removing previous one and adding new one
    helder2.aerodynamic_surfaces.pop(-1)

    fin_set = helder2.add_trapezoidal_fins(
        n=4,
        root_chord=0.150,
        tip_chord=0.100,
        span=0.176,
        position=-1.04956 * factor,
    )
    # Simulate
    print(
        "Simulating Rocket with Static Margin of {:1.3f}->{:1.3f} c".format(
            helder2.static_margin(0),
            helder2.static_margin(helder2.motor.burn_out_time),
        )
    )
    test_flight = Flight(
        rocket=helder2,
        environment=custom_env,
        rail_length=5.2,
        inclination=90,
        heading=0,
        max_time_step=0.01,
        max_time=5,
        terminate_on_apogee=True,
        verbose=True,
    )
    # Store Results
    static_margin_at_ignition = helder2.static_margin(0)
    static_margin_at_out_of_rail = helder2.static_margin(test_flight.out_of_rail_time)
    static_margin_at_steady_state = helder2.static_margin(test_flight.t_final)
    simulation_results += [
        (
            test_flight.attitude_angle,
            "{:1.2f} c | {:1.2f} c | {:1.2f} c".format(
                static_margin_at_ignition,
                static_margin_at_out_of_rail,
                static_margin_at_steady_state,
            ),
        )
    ]

Function.compare_plots(
    simulation_results,
    lower=0,
    upper=1.5,
    xlabel="Time (s)",
    ylabel="Attitude Angle (deg)",
)
# Out:
# Simulating Rocket with Static Margin of -0.389->0.885 c
# Current Simulation Time: 5.0000 s
# >>> Simulation Completed at Time: 5.0000 s
# Simulating Rocket with Static Margin of 0.738->2.012 c
# Current Simulation Time: 5.0000 s
# >>> Simulation Completed at Time: 5.0000 s
# Simulating Rocket with Static Margin of 1.866->3.140 c
# Current Simulation Time: 5.0000 s
# >>> Simulation Completed at Time: 5.0000 s
# Simulating Rocket with Static Margin of 2.993->4.267 c
# Current Simulation Time: 5.0000 s
# >>> Simulation Completed at Time: 5.0000 s
# Simulating Rocket with Static Margin of 4.120->5.394 c
# Current Simulation Time: 5.0000 s
# >>> Simulation Completed at Time: 5.0000 s

# %% [markdown]
# ### Characteristic Frequency Calculation
#
# Here we analyze the characteristic frequency of oscillation of our rocket just as it leaves the launch rail. Note that when we ran test_flight.all_info(), one of the plots already showed us the frequency spectrum of our flight. Here, however, we have more control of what we are plotting.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Simulate first 5 seconds of Flight
flight = Flight(
    rocket=helder2,
    environment=env,
    rail_length=5.2,
    inclination=85,
    heading=90,
    max_time_step=0.01,
    max_time=5,
)

# Perform a Fourier Analysis
Fs = 100.0
# sampling rate
Ts = 1.0 / Fs
# sampling interval
t = np.arange(1, 400, Ts)  # time vector
ff = 5
# frequency of the signal
y = flight.attitude_angle(t) - np.mean(flight.attitude_angle(t))
n = len(y)  # length of the signal
k = np.arange(n)
T = n / Fs
frq = k / T  # two sides frequency range
frq = frq[range(n // 2)]  # one side frequency range
Y = np.fft.fft(y) / n  # fft computing and normalization
Y = Y[range(n // 2)]

# Create the plot
fig, ax = plt.subplots(2, 1)
ax[0].plot(t, y)
ax[0].set_xlabel("Time")
ax[0].set_ylabel("Signal")
ax[0].set_xlim((0, 5))
ax[0].grid()
ax[1].plot(frq, abs(Y), "r")  # plotting the spectrum
ax[1].set_xlabel("Freq (Hz)")
ax[1].set_ylabel("|Y(freq)|")
ax[1].set_xlim((0, 5))
ax[1].grid()
plt.subplots_adjust(hspace=0.5)
plt.show()
